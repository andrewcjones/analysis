# %%
import pandas as pd
import censusdata

# %%
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)

# %%
censusdata.search('acs1', 2019, 'label', 'INCOME IN THE PAST 12 MONTHS \(IN 2019 INFLATION-ADJUSTED DOLLARS\)')
# Out:
# [('B19013A_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013B_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013C_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013D_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (ASIAN ALONE HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013E_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013F_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013G_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (TWO OR MORE RACES HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013H_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013I_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (HISPANIC OR LATINO HOUSEHOLDER)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19013_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025A_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025B_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025C_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025D_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (ASIAN ALONE HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025E_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025F_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025G_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (TWO OR MORE RACES HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025H_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025I_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (HISPANIC OR LATINO HOUSEHOLDER)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19025_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19049_001E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:'),
#  ('B19049_002E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Householder under 25 years'),
#  ('B19049_003E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Householder 25 to 44 years'),
#  ('B19049_004E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Householder 45 to 64 years'),
#  ('B19049_005E',
#   'MEDIAN HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Householder 65 years and over'),
#  ('B19050_001E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars):'),
#  ('B19050_002E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Householder under 25 years'),
#  ('B19050_003E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Householder 25 to 44 years'),
#  ('B19050_004E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Householder 45 to 64 years'),
#  ('B19050_005E',
#   'AGGREGATE HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Householder 65 years and over'),
#  ('B19062_001E',
#   'AGGREGATE WAGE OR SALARY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'Estimate!!Aggregate wage or salary income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19063_001E',
#   'AGGREGATE SELF-EMPLOYMENT INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'Estimate!!Aggregate self-employment income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19064_001E',
#   'AGGREGATE INTEREST, DIVIDENDS, OR NET RENTAL INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'Estimate!!Aggregate interest, dividends, or net rental income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19065_001E',
#   'AGGREGATE SOCIAL SECURITY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'Estimate!!Aggregate Social Security income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19067_001E',
#   'AGGREGATE PUBLIC ASSISTANCE INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'Estimate!!Aggregate public assistance income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19069_001E',
#   'AGGREGATE RETIREMENT INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'Estimate!!Aggregate retirement income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19070_001E',
#   'AGGREGATE OTHER TYPES OF INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR HOUSEHOLDS',
#   'Estimate!!Aggregate other types of income in the past 12 months (in 2019 inflation-adjusted dollars):'),
#  ('B19113A_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113B_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113C_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113D_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (ASIAN ALONE HOUSEHOLDER)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113E_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113F_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113G_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (TWO OR MORE RACES)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113H_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113I_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (HISPANIC OR LATINO HOUSEHOLDER)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19113_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19126_001E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:'),
#  ('B19126_002E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Married-couple family --!!Total'),
#  ('B19126_003E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Married-couple family --!!Total!!With own children of the householder under 18 years'),
#  ('B19126_004E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Married-couple family --!!Total!!No own children of the householder under 18 years'),
#  ('B19126_005E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Other family --!!Total'),
#  ('B19126_006E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Other family --!!Total!!Male householder, no spouse present --!!Total'),
#  ('B19126_007E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Other family --!!Total!!Male householder, no spouse present --!!Total!!With own children of the householder under 18 years'),
#  ('B19126_008E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Other family --!!Total!!Male householder, no spouse present --!!Total!!No own children of the householder under 18 years'),
#  ('B19126_009E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Other family --!!Total!!Female householder, no spouse present --!!Total'),
#  ('B19126_010E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Other family --!!Total!!Female householder, no spouse present --!!Total!!With own children of the householder under 18 years'),
#  ('B19126_011E',
#   'MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Median family income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total:!!Other family --!!Total!!Female householder, no spouse present --!!Total!!No own children of the householder under 18 years'),
#  ('B19127_001E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19128_001E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):'),
#  ('B19128_002E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married-couple family:'),
#  ('B19128_003E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married-couple family:!!With own children of the householder under 18 years'),
#  ('B19128_004E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married-couple family:!!No own children of the householder under 18 years'),
#  ('B19128_005E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family:'),
#  ('B19128_006E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family:!!Male householder, no spouse present:'),
#  ('B19128_007E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family:!!Male householder, no spouse present:!!With own children of the householder under 18 years'),
#  ('B19128_008E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family:!!Male householder, no spouse present:!!No own children of the householder under 18 years'),
#  ('B19128_009E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family:!!Female householder, no spouse present:'),
#  ('B19128_010E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family:!!Female householder, no spouse present:!!With own children of the householder under 18 years'),
#  ('B19128_011E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY PRESENCE OF OWN CHILDREN UNDER 18 YEARS',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family:!!Female householder, no spouse present:!!No own children of the householder under 18 years'),
#  ('B19129_001E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY NUMBER OF WORKERS IN FAMILY',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):'),
#  ('B19129_002E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY NUMBER OF WORKERS IN FAMILY',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!No workers (dollars)'),
#  ('B19129_003E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY NUMBER OF WORKERS IN FAMILY',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!1 worker (dollars)'),
#  ('B19129_004E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY NUMBER OF WORKERS IN FAMILY',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!2 workers, both spouses worked (dollars)'),
#  ('B19129_005E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY NUMBER OF WORKERS IN FAMILY',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!2 workers, other (dollars)'),
#  ('B19129_006E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY NUMBER OF WORKERS IN FAMILY',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!3 or more workers, both spouses worked (dollars)'),
#  ('B19129_007E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY NUMBER OF WORKERS IN FAMILY',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!3 or more workers, other (dollars)'),
#  ('B19130_001E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):'),
#  ('B19130_002E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):'),
#  ('B19130_003E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):!!Householder 15 to 24 years (dollars)'),
#  ('B19130_004E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):!!Householder 25 to 34 years (dollars)'),
#  ('B19130_005E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):!!Householder 35 to 44 years (dollars)'),
#  ('B19130_006E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):!!Householder 45 to 54 years (dollars)'),
#  ('B19130_007E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):!!Householder 55 to 59 years (dollars)'),
#  ('B19130_008E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):!!Householder 60 to 64 years (dollars)'),
#  ('B19130_009E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):!!Householder 65 to 74 years (dollars)'),
#  ('B19130_010E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Married couple family (dollars):!!Householder 75 years and over (dollars)'),
#  ('B19130_011E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):'),
#  ('B19130_012E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):'),
#  ('B19130_013E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):!!Householder 15 to 24 years (dollars)'),
#  ('B19130_014E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):!!Householder 25 to 34 years (dollars)'),
#  ('B19130_015E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):!!Householder 35 to 44 years (dollars)'),
#  ('B19130_016E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):!!Householder 45 to 54 years (dollars)'),
#  ('B19130_017E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):!!Householder 55 to 59 years (dollars)'),
#  ('B19130_018E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):!!Householder 60 to 64 years (dollars)'),
#  ('B19130_019E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):!!Householder 65 to 74 years (dollars)'),
#  ('B19130_020E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Male householder, no spouse present (dollars):!!Householder 75 years and over (dollars)'),
#  ('B19130_021E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):'),
#  ('B19130_022E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):!!Householder 15 to 24 years (dollars)'),
#  ('B19130_023E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):!!Householder 25 to 34 years (dollars)'),
#  ('B19130_024E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):!!Householder 35 to 44 years (dollars)'),
#  ('B19130_025E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):!!Householder 45 to 54 years (dollars)'),
#  ('B19130_026E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):!!Householder 55 to 59 years (dollars)'),
#  ('B19130_027E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):!!Householder 60 to 64 years (dollars)'),
#  ('B19130_028E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):!!Householder 65 to 74 years (dollars)'),
#  ('B19130_029E',
#   'AGGREGATE FAMILY INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY FAMILY TYPE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate family income in the past 12 months (in 2019 inflation-adjusted dollars):!!Other family (dollars):!!Female householder, no spouse present (dollars):!!Householder 75 years and over (dollars)'),
#  ('B19202A_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202B_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202C_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202D_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (ASIAN ALONE HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202E_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202F_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202G_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (TWO OR MORE RACES HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202H_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202I_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (HISPANIC OR LATINO HOUSEHOLDER)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19202_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19214_001E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19215_001E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):'),
#  ('B19215_002E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Male householder --!!Total (dollars)'),
#  ('B19215_003E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Male householder --!!Total (dollars)!!Living alone --!!Total (dollars)'),
#  ('B19215_004E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Male householder --!!Total (dollars)!!Living alone --!!Total (dollars)!!Householder 15 to 64 years (dollars)'),
#  ('B19215_005E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Male householder --!!Total (dollars)!!Living alone --!!Total (dollars)!!Householder 65 years and over (dollars)'),
#  ('B19215_006E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Male householder --!!Total (dollars)!!Not living alone --!!Total (dollars)'),
#  ('B19215_007E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Male householder --!!Total (dollars)!!Not living alone --!!Total (dollars)!!Householder 15 to 64 years (dollars)'),
#  ('B19215_008E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Male householder --!!Total (dollars)!!Not living alone --!!Total (dollars)!!Householder 65 years and over (dollars)'),
#  ('B19215_009E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Female householder --!!Total (dollars)'),
#  ('B19215_010E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Female householder --!!Total (dollars)!!Living alone --!!Total (dollars)'),
#  ('B19215_011E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Female householder --!!Total (dollars)!!Living alone --!!Total (dollars)!!Householder 15 to 64 years (dollars)'),
#  ('B19215_012E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Female householder --!!Total (dollars)!!Living alone --!!Total (dollars)!!Householder 65 years and over (dollars)'),
#  ('B19215_013E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Female householder --!!Total (dollars)!!Not living alone --!!Total (dollars)'),
#  ('B19215_014E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Female householder --!!Total (dollars)!!Not living alone --!!Total (dollars)!!Householder 15 to 64 years (dollars)'),
#  ('B19215_015E',
#   'MEDIAN NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Median nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Total (dollars):!!Female householder --!!Total (dollars)!!Not living alone --!!Total (dollars)!!Householder 65 years and over (dollars)'),
#  ('B19216_001E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):'),
#  ('B19216_002E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Male householder (dollars):'),
#  ('B19216_003E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Male householder (dollars):!!Living alone (dollars):'),
#  ('B19216_004E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Male householder (dollars):!!Living alone (dollars):!!Householder 15 to 64 years (dollars)'),
#  ('B19216_005E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Male householder (dollars):!!Living alone (dollars):!!Householder 65 years and over (dollars)'),
#  ('B19216_006E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Male householder (dollars):!!Not living alone (dollars):'),
#  ('B19216_007E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Male householder (dollars):!!Not living alone (dollars):!!Householder 15 to 64 years (dollars)'),
#  ('B19216_008E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Male householder (dollars):!!Not living alone (dollars):!!Householder 65 years and over (dollars)'),
#  ('B19216_009E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Female householder (dollars):'),
#  ('B19216_010E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Female householder (dollars):!!Living alone (dollars):'),
#  ('B19216_011E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Female householder (dollars):!!Living alone (dollars):!!Householder 15 to 64 years (dollars)'),
#  ('B19216_012E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Female householder (dollars):!!Living alone (dollars):!!Householder 65 years and over (dollars)'),
#  ('B19216_013E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Female householder (dollars):!!Not living alone (dollars):'),
#  ('B19216_014E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Female householder (dollars):!!Not living alone (dollars):!!Householder 15 to 64 years (dollars)'),
#  ('B19216_015E',
#   'AGGREGATE NONFAMILY HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY SEX OF HOUSEHOLDER BY LIVING ALONE BY AGE OF HOUSEHOLDER',
#   'Estimate!!Aggregate nonfamily household income in the past 12 months (in 2019 inflation-adjusted dollars):!!Female householder (dollars):!!Not living alone (dollars):!!Householder 65 years and over (dollars)'),
#  ('B19301A_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301B_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301C_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301D_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (ASIAN ALONE)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301E_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301F_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (SOME OTHER RACE ALONE)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301G_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (TWO OR MORE RACES)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301H_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301I_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (HISPANIC OR LATINO)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19301_001E',
#   'PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Per capita income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19313A_001E',
#   'AGGREGATE INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 15 YEARS AND OVER (WHITE ALONE)',
#   'Estimate!!Aggregate income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19313B_001E',
#   'AGGREGATE INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 15 YEARS AND OVER (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Aggregate income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19313C_001E',
#   'AGGREGATE INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 15 YEARS AND OVER (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Aggregate income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19313D_001E',
#   'AGGREGATE INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR THE POPULATION 15 YEARS AND OVER (ASIAN ALONE)',
#   'Estimate!!Aggregate income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('B19313E_001E',
# ...
#  ('B25122_090E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$100 to $199'),
#  ('B25122_091E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$200 to $299'),
#  ('B25122_092E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$300 to $399'),
#  ('B25122_093E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$400 to $499'),
#  ('B25122_094E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$500 to $599'),
#  ('B25122_095E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$600 to $699'),
#  ('B25122_096E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$700 to $799'),
#  ('B25122_097E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$800 to $899'),
#  ('B25122_098E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$900 to $999'),
#  ('B25122_099E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$1,000 to $1,249'),
#  ('B25122_100E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$1,250 to $1,499'),
#  ('B25122_101E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$1,500 to $1,999'),
#  ('B25122_102E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!With cash rent:!!$2,000 or more'),
#  ('B25122_103E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 to $99,999:!!No cash rent'),
#  ('B25122_104E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:'),
#  ('B25122_105E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:'),
#  ('B25122_106E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!Less than $100'),
#  ('B25122_107E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$100 to $199'),
#  ('B25122_108E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$200 to $299'),
#  ('B25122_109E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$300 to $399'),
#  ('B25122_110E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$400 to $499'),
#  ('B25122_111E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$500 to $599'),
#  ('B25122_112E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$600 to $699'),
#  ('B25122_113E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$700 to $799'),
#  ('B25122_114E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$800 to $899'),
#  ('B25122_115E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$900 to $999'),
#  ('B25122_116E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$1,000 to $1,249'),
#  ('B25122_117E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$1,250 to $1,499'),
#  ('B25122_118E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$1,500 to $1,999'),
#  ('B25122_119E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!With cash rent:!!$2,000 or more'),
#  ('B25122_120E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$100,000 or more:!!No cash rent'),
#  ('B29004_001E',
#   'MEDIAN HOUSEHOLD INCOME FOR HOUSEHOLDS WITH A CITIZEN, VOTING-AGE HOUSEHOLDER (IN 2019 INFLATION-ADJUSTED DOLLARS)',
#   'Estimate!!Median household income in the past 12 months (in 2019 inflation-adjusted dollars)'),
#  ('C25122_002E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Less than $10,000:'),
#  ('C25122_003E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Less than $10,000:!!Less than $500'),
#  ('C25122_004E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Less than $10,000:!!$500 to $999'),
#  ('C25122_005E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Less than $10,000:!!$1,000 or more'),
#  ('C25122_006E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!Less than $10,000:!!No cash rent'),
#  ('C25122_007E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$10,000 to $19,999:'),
#  ('C25122_008E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$10,000 to $19,999:!!Less than $500'),
#  ('C25122_009E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$10,000 to $19,999:!!$500 to $999'),
#  ('C25122_010E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$10,000 to $19,999:!!$1,000 or more'),
#  ('C25122_011E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$10,000 to $19,999:!!No cash rent'),
#  ('C25122_012E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$20,000 to $34,999:'),
#  ('C25122_013E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$20,000 to $34,999:!!Less than $500'),
#  ('C25122_014E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$20,000 to $34,999:!!$500 to $999'),
#  ('C25122_015E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$20,000 to $34,999:!!$1,000 or more'),
#  ('C25122_016E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$20,000 to $34,999:!!No cash rent'),
#  ('C25122_017E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$35,000 to $49,999:'),
#  ('C25122_018E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$35,000 to $49,999:!!Less than $500'),
#  ('C25122_019E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$35,000 to $49,999:!!$500 to $999'),
#  ('C25122_020E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$35,000 to $49,999:!!$1,000 or more'),
#  ('C25122_021E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$35,000 to $49,999:!!No cash rent'),
#  ('C25122_022E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$50,000 to $74,999:'),
#  ('C25122_023E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$50,000 to $74,999:!!Less than $500'),
#  ('C25122_024E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$50,000 to $74,999:!!$500 to $999'),
#  ('C25122_025E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$50,000 to $74,999:!!$1,000 or more'),
#  ('C25122_026E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$50,000 to $74,999:!!No cash rent'),
#  ('C25122_027E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 or more:'),
#  ('C25122_028E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 or more:!!Less than $500'),
#  ('C25122_029E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 or more:!!$500 to $999'),
#  ('C25122_030E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 or more:!!$1,000 or more'),
#  ('C25122_031E',
#   'HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) BY GROSS RENT',
#   'Estimate!!Total:!!Household income in the past 12 months (in 2019 inflation-adjusted dollars) --!!$75,000 or more:!!No cash rent')]

# %%
censusdata.variable_info.censustable('acs1', 2019, '')

# %%
censusdata.printtable(censusdata.censustable('acs1', 2019, 'B01901'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-782a7125e3bc> in <module>
# ----> 1 censusdata.printtable(censusdata.censustable('acs1', 2019, 'B01901'))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/censusdata/variable_info.py in censustable(src, year, table)
#     108                         ret[k] = {'label': allvars[k]['label'], 'concept': allvars[k]['concept'], 'predicateType': allvars[k]['predicateType']}
#     109         if len(ret) == 0:
# --> 110                 raise ValueError(u'Table not found!')
#     111         return ret
#     112
#
# ValueError: Table not found!

# %%
censusdata.download
# Out:
# <function censusdata.download.download(src, year, geo, var, key=None, tabletype='detail', endpt='')>
