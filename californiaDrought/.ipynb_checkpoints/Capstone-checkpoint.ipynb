# %%
from parsons import Table, Redshift
import csv
import datetime
import pytz
import pandas as pd
import numpy as np
import os
from dateutil.relativedelta import relativedelta
from tabulate import tabulate
import seaborn as sns
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt, ticker

import censusdata

# %%
## OLD DATA 
# incomeLevels2010 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2010.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2011 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2011.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2012 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2012.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2013 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2013.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2014 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2014.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2015 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2015.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2016 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2016.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2017 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2017.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2018 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2018.S1901_data_with_overlays_2021-08-02T095806.csv")
# incomeLevels2019 = pd.read_csv("oldData/incomePast12Months_5YearEstimate/ACSST5Y2019.S1901_data_with_overlays_2021-08-02T095806.csv")

# incomeLevelsDF = incomeLevels2010[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]]
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2011[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2012[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2013[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2014[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2015[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2016[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2017[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2018[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])
# incomeLevelsDF = incomeLevelsDF.append(incomeLevels2019[["S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]].loc[[1]])


# incomeLevelsDF = incomeLevelsDF.rename(columns=incomeLevelsDF.iloc[0]).drop(incomeLevelsDF.index[0])

# incomeLevelsDF['year'] = ['2010', '2011', '2012','2013', '2014', '2015', '2016', '2017', '2018', '2019']
# incomeLevelsDF.reset_index(drop=True)

# droughtData = pd.read_csv("comprehensiveDroughtData2010-2020.csv")
# droughtData.head(5)

# %%
#California Income Levels by County in 2019

CAIncomeLevels2019 = pd.read_csv("data/Income_CA_Counties_ACSST5Y2019/CACounties_ACSST5Y2019.S1901_data_with_overlays.csv")
incomeDF = CAIncomeLevels2019[["GEO_ID", "NAME", "S1901_C01_001E", "S1901_C01_002E", "S1901_C01_003E", "S1901_C01_004E", "S1901_C01_005E", "S1901_C01_006E", "S1901_C01_007E", "S1901_C01_008E", "S1901_C01_009E", "S1901_C01_010E", "S1901_C01_011E", "S1901_C01_012E", "S1901_C01_013E"]]

# %%
#California Demographic Data by County in 2019

CAdemographics2019 = pd.read_csv("data/Demographics_CA_Counties_ACSSTY5Y2019/Demographics_CA_Counties_ACSSTY5Y2019_data.csv")
demographicDF = CAdemographics2019[["GEO_ID", "DP05_0001E", "DP05_0002PE", "DP05_0003PE", "DP05_0037PE", "DP05_0038PE", "DP05_0039PE", "DP05_0044PE", "DP05_0071PE"]]

# %%
#California Housing Characteristics by county in 2019

CAHousingCharacteristics2019 = pd.read_csv("data/Housing_Characteristics_CA_Counties_ACSST5Y2019/Housing_Characteristics_CA_Counties_ACSST5Y2019_Data.csv")
housingDF = CAHousingCharacteristics2019[["GEO_ID", "DP04_0001E", "DP04_0002E", "DP04_0002PE", "DP04_0003PE", "DP04_0005M", "DP04_0047E", "DP04_0047PE", "DP04_0127PE", "DP04_0128PE", "DP04_0129PE", "DP04_0131PE", "DP04_0132PE", "DP04_0133PE"]]

# %%
##Combine Dataframes from Census
censusDF = pd.merge(incomeDF, housingDF, on="GEO_ID", )
censusDF = pd.merge(censusDF, demographicDF, on="GEO_ID")

#Change column names to first row
censusDF.columns = censusDF.iloc[0]
censusDF = censusDF.drop(censusDF.index[0])

# %%
##information about new census dataframe
censusDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 1 to 59
# Data columns (total 36 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   id                                                                                        59 non-null     object
#  1   Geographic Area Name                                                                      59 non-null     object
#  2   Estimate!!Households!!Total                                                               59 non-null     object
#  3   Estimate!!Households!!Total!!Less than $10,000                                            59 non-null     object
#  4   Estimate!!Households!!Total!!$10,000 to $14,999                                           59 non-null     object
#  5   Estimate!!Households!!Total!!$15,000 to $24,999                                           59 non-null     object
#  6   Estimate!!Households!!Total!!$25,000 to $34,999                                           59 non-null     object
#  7   Estimate!!Households!!Total!!$35,000 to $49,999                                           59 non-null     object
#  8   Estimate!!Households!!Total!!$50,000 to $74,999                                           59 non-null     object
#  9   Estimate!!Households!!Total!!$75,000 to $99,999                                           59 non-null     object
#  10  Estimate!!Households!!Total!!$100,000 to $149,999                                         59 non-null     object
#  11  Estimate!!Households!!Total!!$150,000 to $199,999                                         59 non-null     object
#  12  Estimate!!Households!!Total!!$200,000 or more                                             59 non-null     object
#  13  Estimate!!Households!!Median income (dollars)                                             59 non-null     object
#  14  Estimate!!Households!!Mean income (dollars)                                               59 non-null     object
#  15  Estimate!!HOUSING OCCUPANCY!!Total housing units                                          59 non-null     object
#  16  Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units                  59 non-null     object
#  17  Percent!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units                   59 non-null     object
#  18  Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units                     59 non-null     object
#  19  Margin of Error!!HOUSING OCCUPANCY!!Total housing units!!Rental vacancy rate              59 non-null     object
#  20  Estimate!!HOUSING TENURE!!Occupied housing units!!Renter-occupied                         59 non-null     object
#  21  Percent!!HOUSING TENURE!!Occupied housing units!!Renter-occupied                          59 non-null     object
#  22  Percent!!GROSS RENT!!Occupied units paying rent!!Less than $500                           59 non-null     object
#  23  Percent!!GROSS RENT!!Occupied units paying rent!!$500 to $999                             59 non-null     object
#  24  Percent!!GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499                         59 non-null     object
#  25  Percent!!GROSS RENT!!Occupied units paying rent!!$2,000 to $2,499                         59 non-null     object
#  26  Percent!!GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999                         59 non-null     object
#  27  Percent!!GROSS RENT!!Occupied units paying rent!!$3,000 or more                           59 non-null     object
#  28  Estimate!!SEX AND AGE!!Total population                                                   59 non-null     object
#  29  Percent!!SEX AND AGE!!Total population!!Male                                              59 non-null     object
#  30  Percent!!SEX AND AGE!!Total population!!Female                                            59 non-null     object
#  31  Percent!!RACE!!Total population!!One race!!White                                          59 non-null     object
#  32  Percent!!RACE!!Total population!!One race!!Black or African American                      59 non-null     object
#  33  Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native              59 non-null     object
#  34  Percent!!RACE!!Total population!!One race!!Asian                                          59 non-null     object
#  35  Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)  59 non-null     object
# dtypes: object(36)
# memory usage: 17.1+ KB

# %%
##Convert Columns to Numeric Where Possible
censusDF = censusDF.apply(pd.to_numeric, errors='ignore')

# %%
##Renaming Columns
            
censusDF.rename(columns = {'Estimate!!Households!!Total':'households_total', 
                           'Estimate!!Households!!Total!!Less than $10,000':'income_less_than_10000',
                           'Estimate!!Households!!Total!!$10,000 to $14,999':'income_10000_to_14999',
                           'Estimate!!Households!!Total!!$15,000 to $24,999':'income_15000_to_24999',
                           'Estimate!!Households!!Total!!$25,000 to $34,999':'income_25000_to_34999',
                           'Estimate!!Households!!Total!!$35,000 to $49,999':'income_35000_to_44999',
                           'Estimate!!Households!!Total!!$50,000 to $74,999':'income_50000_to_74999',
                           'Estimate!!Households!!Total!!$75,000 to $99,999':'income_75000_to_99999',
                           'Estimate!!Households!!Total!!$100,000 to $149,999':'income_100000_to_149999',
                           'Estimate!!Households!!Total!!$150,000 to $199,999':'income_150000_to_199999',
                           'Estimate!!Households!!Total!!$200,000 or more':'income_more_than_200000',
                           'Estimate!!Households!!Median income (dollars)':'median_income',
                           'Estimate!!Households!!Mean income (dollars)':'mean_income',
                           'Estimate!!HOUSING OCCUPANCY!!Total housing units':'totla_housing_units',
                           'Estimate!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units':'occupied_housing_units',
                           'Percent!!HOUSING OCCUPANCY!!Total housing units!!Occupied housing units':'percent_occupied_housing_units',
                           'Percent!!HOUSING OCCUPANCY!!Total housing units!!Vacant housing units':'percent_vacant_housing_units',
                           'Margin of Error!!HOUSING OCCUPANCY!!Total housing units!!Rental vacancy rate':'margin_of_error_rental_vacancy_rate',
                           'Estimate!!HOUSING TENURE!!Occupied housing units!!Renter-occupied':'renter_occupied_units',
                           'Percent!!HOUSING TENURE!!Occupied housing units!!Renter-occupied':'percent_renter_occupied',
                           'Percent!!GROSS RENT!!Occupied units paying rent!!Less than $500':'percent_rent_less_than_500',
                           'Percent!!GROSS RENT!!Occupied units paying rent!!$500 to $999': 'percent_rent_500_to_999',
                           'Percent!!GROSS RENT!!Occupied units paying rent!!$1,000 to $1,499': 'percent_rent_1000_to_1499',
                           'Percent!!GROSS RENT!!Occupied units paying rent!!$2,000 to $2,499':'percent_rent_2000_to_2499',
                           'Percent!!GROSS RENT!!Occupied units paying rent!!$2,500 to $2,999':'percent_rent_2500_to_2999',
                           'Percent!!GROSS RENT!!Occupied units paying rent!!$3,000 or more':'percent_rent_3000_or_more',
                           'Estimate!!SEX AND AGE!!Total population':'total_population',
                           'Percent!!SEX AND AGE!!Total population!!Male':'percent_male',
                           'Percent!!SEX AND AGE!!Total population!!Female':'percent_female',
                           'Percent!!RACE!!Total population!!One race!!White':'percent_white',
                           'Percent!!RACE!!Total population!!One race!!Black or African American':'percent_black_or_african_american',
                           'Percent!!RACE!!Total population!!One race!!American Indian and Alaska Native':'percent_american_indian_and_alaska_native',
                           'Percent!!RACE!!Total population!!One race!!Asian':'percent_asian',
                           'Percent!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)':'percent_hispanic_or_latino'
                          }, inplace = True)

# %%
#Check info again
censusDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 1 to 59
# Data columns (total 36 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   id                                         59 non-null     object
#  1   Geographic Area Name                       59 non-null     object
#  2   households_total                           59 non-null     int64
#  3   income_less_than_10000                     59 non-null     float64
#  4   income_10000_to_14999                      59 non-null     float64
#  5   income_15000_to_24999                      59 non-null     float64
#  6   income_25000_to_34999                      59 non-null     float64
#  7   income_35000_to_44999                      59 non-null     float64
#  8   income_50000_to_74999                      59 non-null     float64
#  9   income_75000_to_99999                      59 non-null     float64
#  10  income_100000_to_149999                    59 non-null     float64
#  11  income_150000_to_199999                    59 non-null     float64
#  12  income_more_than_200000                    59 non-null     float64
#  13  median_income                              59 non-null     int64
#  14  mean_income                                59 non-null     int64
#  15  totla_housing_units                        59 non-null     int64
#  16  occupied_housing_units                     59 non-null     int64
#  17  percent_occupied_housing_units             59 non-null     float64
#  18  percent_vacant_housing_units               59 non-null     float64
#  19  margin_of_error_rental_vacancy_rate        59 non-null     float64
#  20  renter_occupied_units                      59 non-null     int64
#  21  percent_renter_occupied                    59 non-null     float64
#  22  percent_rent_less_than_500                 59 non-null     float64
#  23  percent_rent_500_to_999                    59 non-null     float64
#  24  percent_rent_1000_to_1499                  59 non-null     float64
#  25  percent_rent_2000_to_2499                  59 non-null     float64
#  26  percent_rent_2500_to_2999                  59 non-null     float64
#  27  percent_rent_3000_or_more                  59 non-null     float64
#  28  total_population                           59 non-null     int64
#  29  percent_male                               59 non-null     float64
#  30  percent_female                             59 non-null     float64
#  31  percent_white                              59 non-null     float64
#  32  percent_black_or_african_american          59 non-null     float64
#  33  percent_american_indian_and_alaska_native  59 non-null     float64
#  34  percent_asian                              59 non-null     float64
#  35  percent_hispanic_or_latino                 59 non-null     float64
# dtypes: float64(27), int64(7), object(2)
# memory usage: 17.1+ KB

# %%
#Dropping the 'California' row/total row. Should fix so that it isn't based on Index only. Look up row where 'California' is value for county

censusDF = censusDF.drop(59)

# %%
#Drop 'county' from county name
censusDF['county'] = censusDF['Geographic Area Name']

# censusDF["Geographic Area Name"].series() #.str.split(",")[0]
# censusDF.Geographic


# censusDF["Estimate!!Households!!Total!!Less than $10,000"]

censusDF['county'] = censusDF.county.str.split(",", expand=True)[0].str.replace(" County", "")

# %%
censusDF.shape
# Out:
# (58, 37)

# %%
censusDF.describe()
# Out:
# 0      households_total  income_less_than_10000  income_10000_to_14999  \
# count      5.800000e+01               58.000000              58.000000
# mean       2.249011e+05                5.094828               4.929310
# std        4.825731e+05                1.576407               1.851316
# min        3.500000e+02                2.400000               1.900000
# 25%        1.841125e+04                3.925000               3.400000
# 50%        7.107750e+04                4.800000               4.650000
# 75%        2.187688e+05                6.250000               6.050000
# max        3.316795e+06                9.900000               9.500000
#
# 0      income_15000_to_24999  income_25000_to_34999  income_35000_to_44999  \
# count              58.000000              58.000000              58.000000
# mean                8.844828               8.874138              11.893103
# std                 2.875192               2.503230               2.577831
# min                 4.200000               4.400000               6.200000
# 25%                 6.725000               6.825000              10.150000
# 50%                 8.550000               9.250000              12.050000
# 75%                11.075000              10.500000              13.875000
# max                15.900000              17.300000              16.400000
#
# 0      income_50000_to_74999  income_75000_to_99999  income_100000_to_149999  \
# count              58.000000              58.000000                58.000000
# mean               16.867241              12.536207                15.312069
# std                 2.867629               1.663825                 3.044009
# min                 9.800000               8.600000                 9.100000
# 25%                15.600000              11.725000                12.925000
# 50%                17.250000              12.650000                15.700000
# 75%                18.325000              13.300000                17.225000
# max                25.400000              18.500000                22.400000
#
# 0      income_150000_to_199999  ...  percent_rent_2500_to_2999  \
# count                58.000000  ...                  58.000000
# mean                  7.174138  ...                   3.743103
# std                   2.919298  ...                   4.412705
# min                   2.100000  ...                   0.000000
# 25%                   4.950000  ...                   0.400000
# 50%                   6.550000  ...                   1.600000
# 75%                   9.700000  ...                   5.650000
# max                  13.500000  ...                  17.500000
#
# 0      percent_rent_3000_or_more  total_population  percent_male  \
# count                  58.000000      5.800000e+01     58.000000
# mean                    3.581034      6.773017e+05     50.620690
# std                     5.867109      1.469524e+06      2.505696
# min                     0.000000      1.039000e+03     48.200000
# 25%                     0.425000      4.764675e+04     49.500000
# 50%                     0.900000      1.846320e+05     49.850000
# 75%                     4.325000      6.927508e+05     51.000000
# max                    26.900000      1.008157e+07     66.000000
#
# 0      percent_female  percent_white  percent_black_or_african_american  \
# count       58.000000      58.000000                          58.000000
# mean        49.379310      73.324138                           3.160345
# std          2.505696      13.863296                           2.971085
# min         34.000000      40.500000                           0.100000
# 25%         49.000000      62.150000                           1.125000
# 50%         50.150000      76.300000                           1.950000
# 75%         50.500000      84.500000                           3.400000
# max         51.800000      97.500000                          13.900000
#
# 0      percent_american_indian_and_alaska_native  percent_asian  \
# count                                  58.000000      58.000000
# mean                                    2.274138       7.441379
# std                                     4.654202       8.482615
# min                                     0.400000       0.000000
# 25%                                     0.700000       1.650000
# 50%                                     0.900000       4.300000
# 75%                                     1.875000       7.950000
# max                                    34.000000      36.500000
#
# 0      percent_hispanic_or_latino
# count                   58.000000
# mean                    30.629310
# std                     18.106847
# min                      7.300000
# 25%                     14.675000
# 50%                     25.550000
# 75%                     44.725000
# max                     84.200000
#
# [8 rows x 34 columns]

# %%
censusDF.head(5)
# Out:
# 0              id          Geographic Area Name  households_total  \
# 1  0500000US06001    Alameda County, California            577177
# 2  0500000US06003     Alpine County, California               350
# 3  0500000US06005     Amador County, California             14594
# 4  0500000US06007      Butte County, California             85320
# 5  0500000US06009  Calaveras County, California             16942
#
# 0  income_less_than_10000  income_10000_to_14999  income_15000_to_24999  \
# 1                     4.1                    3.5                    5.5
# 2                     3.1                    5.4                    6.9
# 3                     4.5                    4.1                    9.3
# 4                     7.0                    6.6                   11.3
# 5                     3.7                    3.2                    9.5
#
# 0  income_25000_to_34999  income_35000_to_44999  income_50000_to_74999  \
# 1                    5.5                    7.7                   12.5
# 2                   13.4                    9.4                   17.4
# 3                   10.3                   11.3                   19.6
# 4                   10.2                   13.0                   16.9
# 5                    9.7                   12.3                   20.0
#
# 0  income_75000_to_99999  ...  percent_rent_3000_or_more  total_population  \
# 1                   11.5  ...                       10.1           1656754
# 2                    8.6  ...                        0.0              1039
# 3                   14.2  ...                        0.0             38429
# 4                   11.4  ...                        0.9            225817
# 5                   14.3  ...                        1.2             45514
#
# 0  percent_male  percent_female  percent_white  \
# 1          49.2            50.8           40.5
# 2          53.3            46.7           57.7
# 3          53.7            46.3           86.7
# 4          49.5            50.5           81.6
# 5          49.8            50.2           90.5
#
# 0  percent_black_or_african_american  \
# 1                               10.6
# 2                                0.9
# 3                                2.4
# 4                                1.5
# 5                                0.7
#
# 0  percent_american_indian_and_alaska_native  percent_asian  \
# 1                                        0.7           30.1
# 2                                       34.0            1.0
# 3                                        0.8            1.3
# 4                                        1.2            4.6
# 5                                        0.8            1.5
#
# 0  percent_hispanic_or_latino     county
# 1                        22.4    Alameda
# 2                        12.5     Alpine
# 3                        13.9     Amador
# 4                        16.3      Butte
# 5                        12.1  Calaveras
#
# [5 rows x 37 columns]

# %%
# California 2015-2019 Weekly Drought Metrics by County

# Drought Metrics
# D0 (Abnormally Dry)
# D1 (Moderate Drought)
# D2 (Severe Drought)
# D3 (Extreme Drought)
# D4 (Exceptional Drought)

droughtDF = pd.read_csv("data/droughtMonitor2015_2019CACounties.csv")
droughtDF
# Out:
#         MapDate  FIPS          County State   None     D0     D1     D2  \
# 0      20191231  6001  Alameda County    CA  100.0    0.0    0.0    0.0
# 1      20191224  6001  Alameda County    CA  100.0    0.0    0.0    0.0
# 2      20191217  6001  Alameda County    CA  100.0    0.0    0.0    0.0
# 3      20191210  6001  Alameda County    CA  100.0    0.0    0.0    0.0
# 4      20191203  6001  Alameda County    CA    0.0  100.0    0.0    0.0
# ...         ...   ...             ...   ...    ...    ...    ...    ...
# 15191  20150127  6115     Yuba County    CA    0.0  100.0  100.0  100.0
# 15192  20150120  6115     Yuba County    CA    0.0  100.0  100.0  100.0
# 15193  20150113  6115     Yuba County    CA    0.0  100.0  100.0  100.0
# 15194  20150106  6115     Yuba County    CA    0.0  100.0  100.0  100.0
# 15195  20141230  6115     Yuba County    CA    0.0  100.0  100.0  100.0
#
#           D3     D4  ValidStart    ValidEnd  StatisticFormatID
# 0        0.0   0.00  2019-12-31  2020-01-06                  1
# 1        0.0   0.00  2019-12-24  2019-12-30                  1
# 2        0.0   0.00  2019-12-17  2019-12-23                  1
# 3        0.0   0.00  2019-12-10  2019-12-16                  1
# 4        0.0   0.00  2019-12-03  2019-12-09                  1
# ...      ...    ...         ...         ...                ...
# 15191  100.0  99.78  2015-01-27  2015-02-02                  1
# 15192  100.0  99.78  2015-01-20  2015-01-26                  1
# 15193  100.0  99.78  2015-01-13  2015-01-19                  1
# 15194  100.0   0.00  2015-01-06  2015-01-12                  1
# 15195  100.0   0.00  2014-12-30  2015-01-05                  1
#
# [15196 rows x 13 columns]

# %%
droughtDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15196 entries, 0 to 15195
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MapDate            15196 non-null  int64
#  1   FIPS               15196 non-null  int64
#  2   County             15196 non-null  object
#  3   State              15196 non-null  object
#  4   None               15196 non-null  float64
#  5   D0                 15196 non-null  float64
#  6   D1                 15196 non-null  float64
#  7   D2                 15196 non-null  float64
#  8   D3                 15196 non-null  float64
#  9   D4                 15196 non-null  float64
#  10  ValidStart         15196 non-null  object
#  11  ValidEnd           15196 non-null  object
#  12  StatisticFormatID  15196 non-null  int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
droughtDF.describe()
# Out:
#             MapDate         FIPS          None            D0            D1  \
# count  1.519600e+04  15196.00000  15196.000000  15196.000000  15196.000000
# mean   2.017063e+07   6058.00000     38.084714     61.915286     46.167013
# std    1.426078e+04     33.48244     46.638060     46.638060     48.030684
# min    2.014123e+07   6001.00000      0.000000      0.000000      0.000000
# 25%    2.016033e+07   6029.00000      0.000000      0.000000      0.000000
# 50%    2.017067e+07   6058.00000      0.000000    100.000000     11.290000
# 75%    2.018100e+07   6087.00000    100.000000    100.000000    100.000000
# max    2.019123e+07   6115.00000    100.000000    100.000000    100.000000
#
#                  D2            D3            D4  StatisticFormatID
# count  15196.000000  15196.000000  15196.000000            15196.0
# mean      35.522253     25.932301     15.958987                1.0
# std       46.084624     41.537178     33.951601                0.0
# min        0.000000      0.000000      0.000000                1.0
# 25%        0.000000      0.000000      0.000000                1.0
# 50%        0.000000      0.000000      0.000000                1.0
# 75%      100.000000     64.330000      0.000000                1.0
# max      100.000000    100.000000    100.000000                1.0

# %%
## Defining drought as mean of the drought 

# droughtDF.groupby(['County']).agg({'None': ['mean', 'max'], 'D0': ['mean', 'max'], 'D1': ['mean', 'max'], 'D2': ['mean', 'max'], 'D3': ['mean', 'max'], 'D4': ['mean', 'max']})

# droughtMeanDF = droughtDF.groupby(['County']).agg({'None': ['mean'], 'D0': ['mean']})
# droughtMeanDF['drought'] = 100-droughtMeanDF['None']-droughtMeanDF['D0']

droughtMeanDF = droughtDF.groupby(['County']).agg({'None': ['mean']})
droughtMeanDF['drought'] = 100-droughtMeanDF['None']

# %%
droughtMeanDF['county'] = droughtMeanDF.index.str.replace(" County", "")
droughtMeanDF.columns = droughtMeanDF.columns.droplevel()
droughtMeanDF.columns = ['none', 'drought', 'county']
droughtMeanDF.reset_index(drop=True, inplace=True)

# %%
mergedDF = pd.merge(droughtMeanDF, censusDF, on="county", )

# %%
mergedDF.columns
# Out:
# Index(['none', 'drought', 'county', 'id', 'Geographic Area Name',
#        'households_total', 'income_less_than_10000', 'income_10000_to_14999',
#        'income_15000_to_24999', 'income_25000_to_34999',
#        'income_35000_to_44999', 'income_50000_to_74999',
#        'income_75000_to_99999', 'income_100000_to_149999',
#        'income_150000_to_199999', 'income_more_than_200000', 'median_income',
#        'mean_income', 'totla_housing_units', 'occupied_housing_units',
#        'percent_occupied_housing_units', 'percent_vacant_housing_units',
#        'margin_of_error_rental_vacancy_rate', 'renter_occupied_units',
#        'percent_renter_occupied', 'percent_rent_less_than_500',
#        'percent_rent_500_to_999', 'percent_rent_1000_to_1499',
#        'percent_rent_2000_to_2499', 'percent_rent_2500_to_2999',
#        'percent_rent_3000_or_more', 'total_population', 'percent_male',
#        'percent_female', 'percent_white', 'percent_black_or_african_american',
#        'percent_american_indian_and_alaska_native', 'percent_asian',
#        'percent_hispanic_or_latino'],
#       dtype='object')

# %%
correlationDF = mergedDF.corr()

# %%
mergedDF.head(5)
# Out:
#         none    drought     county              id  \
# 0  41.416832  58.583168    Alameda  0500000US06001
# 1  46.381718  53.618282     Alpine  0500000US06003
# 2  51.215305  48.784695     Amador  0500000US06005
# 3  43.132863  56.867137      Butte  0500000US06007
# 4  48.396908  51.603092  Calaveras  0500000US06009
#
#            Geographic Area Name  households_total  income_less_than_10000  \
# 0    Alameda County, California            577177                     4.1
# 1     Alpine County, California               350                     3.1
# 2     Amador County, California             14594                     4.5
# 3      Butte County, California             85320                     7.0
# 4  Calaveras County, California             16942                     3.7
#
#    income_10000_to_14999  income_15000_to_24999  income_25000_to_34999  ...  \
# 0                    3.5                    5.5                    5.5  ...
# 1                    5.4                    6.9                   13.4  ...
# 2                    4.1                    9.3                   10.3  ...
# 3                    6.6                   11.3                   10.2  ...
# 4                    3.2                    9.5                    9.7  ...
#
#    percent_rent_2500_to_2999  percent_rent_3000_or_more  total_population  \
# 0                       11.3                       10.1           1656754
# 1                        0.0                        0.0              1039
# 2                        0.0                        0.0             38429
# 3                        1.5                        0.9            225817
# 4                        2.5                        1.2             45514
#
#    percent_male  percent_female  percent_white  \
# 0          49.2            50.8           40.5
# 1          53.3            46.7           57.7
# 2          53.7            46.3           86.7
# 3          49.5            50.5           81.6
# 4          49.8            50.2           90.5
#
#    percent_black_or_african_american  \
# 0                               10.6
# 1                                0.9
# 2                                2.4
# 3                                1.5
# 4                                0.7
#
#    percent_american_indian_and_alaska_native  percent_asian  \
# 0                                        0.7           30.1
# 1                                       34.0            1.0
# 2                                        0.8            1.3
# 3                                        1.2            4.6
# 4                                        0.8            1.5
#
#    percent_hispanic_or_latino
# 0                        22.4
# 1                        12.5
# 2                        13.9
# 3                        16.3
# 4                        12.1
#
# [5 rows x 39 columns]

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
correlationHeatMap = sns.heatmap(correlationDF[['drought']], cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


correlationHeatMap.figure.savefig('images/CorrelationHeatMap.png')

# %%
correlationDF
# Out:
#                                                none   drought  \
# none                                       1.000000 -1.000000
# drought                                   -1.000000  1.000000
# households_total                          -0.456885  0.456885
# income_less_than_10000                     0.061087 -0.061087
# income_10000_to_14999                      0.198805 -0.198805
# income_15000_to_24999                      0.150104 -0.150104
# income_25000_to_34999                      0.209303 -0.209303
# income_35000_to_44999                      0.057133 -0.057133
# income_50000_to_74999                      0.051268 -0.051268
# income_75000_to_99999                     -0.125363  0.125363
# income_100000_to_149999                   -0.235277  0.235277
# income_150000_to_199999                   -0.155791  0.155791
# income_more_than_200000                   -0.046461  0.046461
# median_income                             -0.091994  0.091994
# mean_income                               -0.063127  0.063127
# totla_housing_units                       -0.460429  0.460429
# occupied_housing_units                    -0.456885  0.456885
# percent_occupied_housing_units            -0.312144  0.312144
# percent_vacant_housing_units               0.312144 -0.312144
# margin_of_error_rental_vacancy_rate        0.185651 -0.185651
# renter_occupied_units                     -0.422258  0.422258
# percent_renter_occupied                   -0.398381  0.398381
# percent_rent_less_than_500                 0.218814 -0.218814
# percent_rent_500_to_999                    0.262390 -0.262390
# percent_rent_1000_to_1499                  0.071976 -0.071976
# percent_rent_2000_to_2499                 -0.255404  0.255404
# percent_rent_2500_to_2999                 -0.190993  0.190993
# percent_rent_3000_or_more                 -0.054421  0.054421
# total_population                          -0.469157  0.469157
# percent_male                               0.161964 -0.161964
# percent_female                            -0.161964  0.161964
# percent_white                              0.246366 -0.246366
# percent_black_or_african_american         -0.126496  0.126496
# percent_american_indian_and_alaska_native  0.169621 -0.169621
# percent_asian                             -0.078457  0.078457
# percent_hispanic_or_latino                -0.647677  0.647677
#
#                                            households_total  \
# none                                              -0.456885
# drought                                            0.456885
# households_total                                   1.000000
# income_less_than_10000                            -0.083017
# income_10000_to_14999                             -0.209833
# income_15000_to_24999                             -0.224877
# income_25000_to_34999                             -0.258780
# income_35000_to_44999                             -0.264378
# income_50000_to_74999                             -0.224325
# income_75000_to_99999                             -0.036039
# income_100000_to_149999                            0.206239
# income_150000_to_199999                            0.285012
# income_more_than_200000                            0.252128
# median_income                                      0.238520
# mean_income                                        0.251304
# totla_housing_units                                0.999768
# occupied_housing_units                             1.000000
# percent_occupied_housing_units                     0.255363
# percent_vacant_housing_units                      -0.255363
# margin_of_error_rental_vacancy_rate               -0.195499
# renter_occupied_units                              0.993215
# percent_renter_occupied                            0.412097
# percent_rent_less_than_500                        -0.318891
# percent_rent_500_to_999                           -0.380599
# percent_rent_1000_to_1499                         -0.025069
# percent_rent_2000_to_2499                          0.338013
# percent_rent_2500_to_2999                          0.327905
# percent_rent_3000_or_more                          0.237751
# total_population                                   0.999117
# percent_male                                      -0.173511
# percent_female                                     0.173511
# percent_white                                     -0.462402
# percent_black_or_african_american                  0.412426
# percent_american_indian_and_alaska_native         -0.152422
# percent_asian                                      0.404750
# percent_hispanic_or_latino                         0.197088
#
#                                            income_less_than_10000  \
# none                                                     0.061087
# drought                                                 -0.061087
# households_total                                        -0.083017
# income_less_than_10000                                   1.000000
# income_10000_to_14999                                    0.711683
# income_15000_to_24999                                    0.787237
# income_25000_to_34999                                    0.614961
# income_35000_to_44999                                    0.584108
# income_50000_to_74999                                    0.276748
# income_75000_to_99999                                   -0.317044
# income_100000_to_149999                                 -0.758651
# income_150000_to_199999                                 -0.713944
# income_more_than_200000                                 -0.587332
# median_income                                           -0.712395
# mean_income                                             -0.671073
# totla_housing_units                                     -0.080870
# occupied_housing_units                                  -0.083017
# percent_occupied_housing_units                          -0.042700
# percent_vacant_housing_units                             0.042700
# margin_of_error_rental_vacancy_rate                     -0.163366
# renter_occupied_units                                   -0.056067
# percent_renter_occupied                                  0.095325
# percent_rent_less_than_500                               0.432591
# percent_rent_500_to_999                                  0.678723
# percent_rent_1000_to_1499                                0.128357
# percent_rent_2000_to_2499                               -0.623255
# percent_rent_2500_to_2999                               -0.573656
# percent_rent_3000_or_more                               -0.486761
# total_population                                        -0.076412
# percent_male                                            -0.035593
# percent_female                                           0.035593
# percent_white                                            0.226250
# percent_black_or_african_american                       -0.111182
# percent_american_indian_and_alaska_native               -0.009392
# percent_asian                                           -0.310490
# percent_hispanic_or_latino                               0.004461
#
#                                            income_10000_to_14999  \
# none                                                    0.198805
# drought                                                -0.198805
# households_total                                       -0.209833
# income_less_than_10000                                  0.711683
# income_10000_to_14999                                   1.000000
# income_15000_to_24999                                   0.777753
# income_25000_to_34999                                   0.610796
# income_35000_to_44999                                   0.637078
# income_50000_to_74999                                   0.171330
# income_75000_to_99999                                  -0.234666
# income_100000_to_149999                                -0.644235
# income_150000_to_199999                                -0.741371
# income_more_than_200000                                -0.629718
# median_income                                          -0.740476
# mean_income                                            -0.681062
# totla_housing_units                                    -0.208900
# occupied_housing_units                                 -0.209833
# percent_occupied_housing_units                         -0.240662
# percent_vacant_housing_units                            0.240662
# margin_of_error_rental_vacancy_rate                     0.078746
# renter_occupied_units                                  -0.167606
# percent_renter_occupied                                -0.070553
# percent_rent_less_than_500                              0.602644
# percent_rent_500_to_999                                 0.766666
# percent_rent_1000_to_1499                               0.217559
# percent_rent_2000_to_2499                              -0.778811
# percent_rent_2500_to_2999                              -0.658612
# percent_rent_3000_or_more                              -0.520988
# total_population                                       -0.205806
# percent_male                                            0.177619
# percent_female                                         -0.177619
# percent_white                                           0.329893
# percent_black_or_african_american                      -0.228571
# percent_american_indian_and_alaska_native               0.202315
# percent_asian                                          -0.429805
# percent_hispanic_or_latino                             -0.040592
#
#                                            income_15000_to_24999  \
# none                                                    0.150104
# drought                                                -0.150104
# households_total                                       -0.224877
# income_less_than_10000                                  0.787237
# income_10000_to_14999                                   0.777753
# income_15000_to_24999                                   1.000000
# income_25000_to_34999                                   0.816921
# income_35000_to_44999                                   0.678859
# income_50000_to_74999                                   0.430108
# income_75000_to_99999                                  -0.218515
# income_100000_to_149999                                -0.781509
# income_150000_to_199999                                -0.849343
# income_more_than_200000                                -0.774401
# median_income                                          -0.855155
# mean_income                                            -0.829715
# totla_housing_units                                    -0.223473
# occupied_housing_units                                 -0.224877
# percent_occupied_housing_units                         -0.135401
# percent_vacant_housing_units                            0.135401
# margin_of_error_rental_vacancy_rate                    -0.032394
# renter_occupied_units                                  -0.188989
# percent_renter_occupied                                -0.144312
# percent_rent_less_than_500                              0.591357
# percent_rent_500_to_999                                 0.841875
# percent_rent_1000_to_1499                               0.228815
# percent_rent_2000_to_2499                              -0.820421
# percent_rent_2500_to_2999                              -0.747299
# percent_rent_3000_or_more                              -0.627798
# total_population                                       -0.214464
# percent_male                                            0.216721
# percent_female                                         -0.216721
# percent_white                                           0.455360
# percent_black_or_african_american                      -0.229334
# percent_american_indian_and_alaska_native               0.102047
# percent_asian                                          -0.539619
# percent_hispanic_or_latino                              0.000850
#
#                                            income_25000_to_34999  \
# none                                                    0.209303
# drought                                                -0.209303
# households_total                                       -0.258780
# income_less_than_10000                                  0.614961
# income_10000_to_14999                                   0.610796
# income_15000_to_24999                                   0.816921
# income_25000_to_34999                                   1.000000
# income_35000_to_44999                                   0.642658
# income_50000_to_74999                                   0.603206
# income_75000_to_99999                                  -0.172432
# income_100000_to_149999                                -0.615686
# income_150000_to_199999                                -0.893794
# income_more_than_200000                                -0.803721
# median_income                                          -0.854178
# mean_income                                            -0.827546
# totla_housing_units                                    -0.257005
# occupied_housing_units                                 -0.258780
# percent_occupied_housing_units                         -0.401393
# percent_vacant_housing_units                            0.401393
# margin_of_error_rental_vacancy_rate                     0.289034
# renter_occupied_units                                  -0.224188
# percent_renter_occupied                                -0.361308
# percent_rent_less_than_500                              0.707767
# percent_rent_500_to_999                                 0.848715
# percent_rent_1000_to_1499                               0.229293
# percent_rent_2000_to_2499                              -0.834484
# percent_rent_2500_to_2999                              -0.815338
# percent_rent_3000_or_more                              -0.703366
# total_population                                       -0.246246
# percent_male                                            0.279174
# percent_female                                         -0.279174
# percent_white                                           0.405079
# percent_black_or_african_american                      -0.218952
# percent_american_indian_and_alaska_native               0.448245
# percent_asian                                          -0.614994
# percent_hispanic_or_latino                             -0.081785
#
#                                            income_35000_to_44999  \
# none                                                    0.057133
# drought                                                -0.057133
# households_total                                       -0.264378
# income_less_than_10000                                  0.584108
# income_10000_to_14999                                   0.637078
# income_15000_to_24999                                   0.678859
# income_25000_to_34999                                   0.642658
# income_35000_to_44999                                   1.000000
# income_50000_to_74999                                   0.665743
# income_75000_to_99999                                   0.220612
# income_100000_to_149999                                -0.688737
# income_150000_to_199999                                -0.822868
# income_more_than_200000                                -0.868726
# median_income                                          -0.877941
# mean_income                                            -0.872871
# totla_housing_units                                    -0.261530
# occupied_housing_units                                 -0.264378
# percent_occupied_housing_units                         -0.257710
# percent_vacant_housing_units                            0.257710
# margin_of_error_rental_vacancy_rate                     0.081479
# renter_occupied_units                                  -0.230625
# percent_renter_occupied                                -0.139724
# percent_rent_less_than_500                              0.405940
# percent_rent_500_to_999                                 0.731295
# percent_rent_1000_to_1499                               0.511474
# percent_rent_2000_to_2499                              -0.789298
# percent_rent_2500_to_2999                              -0.833858
# percent_rent_3000_or_more                              -0.761355
# total_population                                       -0.249298
# percent_male                                            0.162580
# percent_female                                         -0.162580
# percent_white                                           0.474162
# percent_black_or_african_american                      -0.228160
# percent_american_indian_and_alaska_native               0.085162
# percent_asian                                          -0.669561
# percent_hispanic_or_latino                              0.105614
#
#                                            income_50000_to_74999  \
# none                                                    0.051268
# drought                                                -0.051268
# households_total                                       -0.224325
# income_less_than_10000                                  0.276748
# income_10000_to_14999                                   0.171330
# income_15000_to_24999                                   0.430108
# income_25000_to_34999                                   0.603206
# income_35000_to_44999                                   0.665743
# income_50000_to_74999                                   1.000000
# income_75000_to_99999                                   0.405569
# income_100000_to_149999                                -0.451680
# income_150000_to_199999                                -0.707037
# income_more_than_200000                                -0.767033
# median_income                                          -0.702952
# mean_income                                            -0.741913
# totla_housing_units                                    -0.221245
# occupied_housing_units                                 -0.224325
# percent_occupied_housing_units                         -0.315509
# percent_vacant_housing_units                            0.315509
# margin_of_error_rental_vacancy_rate                     0.249618
# renter_occupied_units                                  -0.201853
# percent_renter_occupied                                -0.201184
# percent_rent_less_than_500                              0.275498
# percent_rent_500_to_999                                 0.568555
# percent_rent_1000_to_1499                               0.514269
# percent_rent_2000_to_2499                              -0.616520
# percent_rent_2500_to_2999                              -0.751414
# percent_rent_3000_or_more                              -0.719678
# total_population                                       -0.209002
# percent_male                                            0.343067
# percent_female                                         -0.343067
# percent_white                                           0.384332
# percent_black_or_african_american                      -0.093476
# percent_american_indian_and_alaska_native               0.200684
# percent_asian                                          -0.601974
# percent_hispanic_or_latino                              0.122662
#
#                                            income_75000_to_99999  ...  \
# none                                                   -0.125363  ...
# drought                                                 0.125363  ...
# households_total                                       -0.036039  ...
# income_less_than_10000                                 -0.317044  ...
# income_10000_to_14999                                  -0.234666  ...
# income_15000_to_24999                                  -0.218515  ...
# income_25000_to_34999                                  -0.172432  ...
# income_35000_to_44999                                   0.220612  ...
# income_50000_to_74999                                   0.405569  ...
# income_75000_to_99999                                   1.000000  ...
# income_100000_to_149999                                 0.069399  ...
# income_150000_to_199999                                 0.081356  ...
# income_more_than_200000                                -0.265264  ...
# median_income                                          -0.104547  ...
# mean_income                                            -0.175579  ...
# totla_housing_units                                    -0.032603  ...
# occupied_housing_units                                 -0.036039  ...
# percent_occupied_housing_units                         -0.109092  ...
# percent_vacant_housing_units                            0.109092  ...
# margin_of_error_rental_vacancy_rate                    -0.061335  ...
# renter_occupied_units                                  -0.048536  ...
# percent_renter_occupied                                -0.122117  ...
# percent_rent_less_than_500                             -0.346973  ...
# percent_rent_500_to_999                                -0.174203  ...
# percent_rent_1000_to_1499                               0.629564  ...
# percent_rent_2000_to_2499                               0.031813  ...
# percent_rent_2500_to_2999                              -0.171713  ...
# percent_rent_3000_or_more                              -0.326783  ...
# total_population                                       -0.026456  ...
# percent_male                                            0.023846  ...
# percent_female                                         -0.023846  ...
# percent_white                                           0.261080  ...
# percent_black_or_african_american                       0.044374  ...
# percent_american_indian_and_alaska_native              -0.356745  ...
# percent_asian                                          -0.283871  ...
# percent_hispanic_or_latino                              0.190913  ...
#
#                                            percent_rent_2500_to_2999  \
# none                                                       -0.190993
# drought                                                     0.190993
# households_total                                            0.327905
# income_less_than_10000                                     -0.573656
# income_10000_to_14999                                      -0.658612
# income_15000_to_24999                                      -0.747299
# income_25000_to_34999                                      -0.815338
# income_35000_to_44999                                      -0.833858
# income_50000_to_74999                                      -0.751414
# income_75000_to_99999                                      -0.171713
# income_100000_to_149999                                     0.577528
# income_150000_to_199999                                     0.888190
# income_more_than_200000                                     0.945150
# median_income                                               0.944661
# mean_income                                                 0.940679
# totla_housing_units                                         0.324462
# occupied_housing_units                                      0.327905
# percent_occupied_housing_units                              0.384205
# percent_vacant_housing_units                               -0.384205
# margin_of_error_rental_vacancy_rate                        -0.271203
# renter_occupied_units                                       0.287251
# percent_renter_occupied                                     0.297332
# percent_rent_less_than_500                                 -0.531074
# percent_rent_500_to_999                                    -0.849429
# percent_rent_1000_to_1499                                  -0.587980
# percent_rent_2000_to_2499                                   0.922361
# percent_rent_2500_to_2999                                   1.000000
# percent_rent_3000_or_more                                   0.909683
# total_population                                            0.313697
# percent_male                                               -0.298062
# percent_female                                              0.298062
# percent_white                                              -0.499465
# percent_black_or_african_american                           0.186243
# percent_american_indian_and_alaska_native                  -0.279953
# percent_asian                                               0.734416
# percent_hispanic_or_latino                                 -0.056615
#
#                                            percent_rent_3000_or_more  \
# none                                                       -0.054421
# drought                                                     0.054421
# households_total                                            0.237751
# income_less_than_10000                                     -0.486761
# income_10000_to_14999                                      -0.520988
# income_15000_to_24999                                      -0.627798
# income_25000_to_34999                                      -0.703366
# income_35000_to_44999                                      -0.761355
# income_50000_to_74999                                      -0.719678
# income_75000_to_99999                                      -0.326783
# income_100000_to_149999                                     0.377265
# income_150000_to_199999                                     0.752639
# income_more_than_200000                                     0.939869
# median_income                                               0.894179
# mean_income                                                 0.917353
# totla_housing_units                                         0.233496
# occupied_housing_units                                      0.237751
# percent_occupied_housing_units                              0.304252
# percent_vacant_housing_units                               -0.304252
# margin_of_error_rental_vacancy_rate                        -0.197949
# renter_occupied_units                                       0.218302
# percent_renter_occupied                                     0.345369
# percent_rent_less_than_500                                 -0.391554
# percent_rent_500_to_999                                    -0.678578
# percent_rent_1000_to_1499                                  -0.624775
# percent_rent_2000_to_2499                                   0.739620
# percent_rent_2500_to_2999                                   0.909683
# percent_rent_3000_or_more                                   1.000000
# total_population                                            0.221190
# percent_male                                               -0.156554
# percent_female                                              0.156554
# percent_white                                              -0.506569
# percent_black_or_african_american                           0.095900
# percent_american_indian_and_alaska_native                  -0.206015
# percent_asian                                               0.759435
# percent_hispanic_or_latino                                 -0.085035
#
#                                            total_population  percent_male  \
# none                                              -0.469157      0.161964
# drought                                            0.469157     -0.161964
# households_total                                   0.999117     -0.173511
# income_less_than_10000                            -0.076412     -0.035593
# income_10000_to_14999                             -0.205806      0.177619
# income_15000_to_24999                             -0.214464      0.216721
# income_25000_to_34999                             -0.246246      0.279174
# income_35000_to_44999                             -0.249298      0.162580
# income_50000_to_74999                             -0.209002      0.343067
# income_75000_to_99999                             -0.026456      0.023846
# income_100000_to_149999                            0.201239     -0.145608
# income_150000_to_199999                            0.271850     -0.265546
# income_more_than_200000                            0.234218     -0.263779
# median_income                                      0.222673     -0.237522
# mean_income                                        0.234662     -0.249315
# totla_housing_units                                0.999385     -0.173578
# occupied_housing_units                             0.999117     -0.173511
# percent_occupied_housing_units                     0.252566     -0.355956
# percent_vacant_housing_units                      -0.252566      0.355956
# margin_of_error_rental_vacancy_rate               -0.194488      0.243173
# renter_occupied_units                              0.990620     -0.150457
# percent_renter_occupied                            0.404884     -0.189337
# percent_rent_less_than_500                        -0.317706      0.257200
# percent_rent_500_to_999                           -0.370259      0.348159
# percent_rent_1000_to_1499                         -0.014001      0.078089
# percent_rent_2000_to_2499                          0.327226     -0.351789
# percent_rent_2500_to_2999                          0.313697     -0.298062
# percent_rent_3000_or_more                          0.221190     -0.156554
# total_population                                   1.000000     -0.170032
# percent_male                                      -0.170032      1.000000
# percent_female                                     0.170032     -1.000000
# percent_white                                     -0.460406      0.166893
# percent_black_or_african_american                  0.412999      0.129488
# percent_american_indian_and_alaska_native         -0.151351      0.217773
# percent_asian                                      0.389337     -0.227696
# percent_hispanic_or_latino                         0.217526     -0.089337
#
#                                            percent_female  percent_white  \
# none                                            -0.161964       0.246366
# drought                                          0.161964      -0.246366
# households_total                                 0.173511      -0.462402
# income_less_than_10000                           0.035593       0.226250
# income_10000_to_14999                           -0.177619       0.329893
# income_15000_to_24999                           -0.216721       0.455360
# income_25000_to_34999                           -0.279174       0.405079
# income_35000_to_44999                           -0.162580       0.474162
# income_50000_to_74999                           -0.343067       0.384332
# income_75000_to_99999                           -0.023846       0.261080
# income_100000_to_149999                          0.145608      -0.368794
# income_150000_to_199999                          0.265546      -0.441764
# income_more_than_200000                          0.263779      -0.524913
# median_income                                    0.237522      -0.505908
# mean_income                                      0.249315      -0.503150
# totla_housing_units                              0.173578      -0.459908
# occupied_housing_units                           0.173511      -0.462402
# percent_occupied_housing_units                   0.355956      -0.376942
# percent_vacant_housing_units                    -0.355956       0.376942
# margin_of_error_rental_vacancy_rate             -0.243173       0.073902
# renter_occupied_units                            0.150457      -0.433223
# percent_renter_occupied                          0.189337      -0.602923
# percent_rent_less_than_500                      -0.257200       0.298274
# percent_rent_500_to_999                         -0.348159       0.443122
# percent_rent_1000_to_1499                       -0.078089       0.309535
# percent_rent_2000_to_2499                        0.351789      -0.453155
# percent_rent_2500_to_2999                        0.298062      -0.499465
# percent_rent_3000_or_more                        0.156554      -0.506569
# total_population                                 0.170032      -0.460406
# percent_male                                    -1.000000       0.166893
# percent_female                                   1.000000      -0.166893
# percent_white                                   -0.166893       1.000000
# percent_black_or_african_american               -0.129488      -0.640076
# percent_american_indian_and_alaska_native       -0.217773      -0.005858
# percent_asian                                    0.227696      -0.784975
# percent_hispanic_or_latino                       0.089337      -0.359258
#
#                                            percent_black_or_african_american  \
# none                                                               -0.126496
# drought                                                             0.126496
# households_total                                                    0.412426
# income_less_than_10000                                             -0.111182
# income_10000_to_14999                                              -0.228571
# income_15000_to_24999                                              -0.229334
# income_25000_to_34999                                              -0.218952
# income_35000_to_44999                                              -0.228160
# income_50000_to_74999                                              -0.093476
# income_75000_to_99999                                               0.044374
# income_100000_to_149999                                             0.264026
# income_150000_to_199999                                             0.254396
# income_more_than_200000                                             0.153586
# median_income                                                       0.206355
# mean_income                                                         0.160378
# totla_housing_units                                                 0.412709
# occupied_housing_units                                              0.412426
# percent_occupied_housing_units                                      0.350064
# percent_vacant_housing_units                                       -0.350064
# margin_of_error_rental_vacancy_rate                                -0.240677
# renter_occupied_units                                               0.383363
# percent_renter_occupied                                             0.375262
# percent_rent_less_than_500                                         -0.310369
# percent_rent_500_to_999                                            -0.268228
# percent_rent_1000_to_1499                                           0.052836
# percent_rent_2000_to_2499                                           0.235121
# percent_rent_2500_to_2999                                           0.186243
# percent_rent_3000_or_more                                           0.095900
# total_population                                                    0.412999
# percent_male                                                        0.129488
# percent_female                                                     -0.129488
# percent_white                                                      -0.640076
# percent_black_or_african_american                                   1.000000
# percent_american_indian_and_alaska_native                          -0.196955
# percent_asian                                                       0.454211
# percent_hispanic_or_latino                                          0.195438
#
#                                            percent_american_indian_and_alaska_native  \
# none                                                                        0.169621
# drought                                                                    -0.169621
# households_total                                                           -0.152422
# income_less_than_10000                                                     -0.009392
# income_10000_to_14999                                                       0.202315
# income_15000_to_24999                                                       0.102047
# income_25000_to_34999                                                       0.448245
# income_35000_to_44999                                                       0.085162
# income_50000_to_74999                                                       0.200684
# income_75000_to_99999                                                      -0.356745
# income_100000_to_149999                                                     0.053667
# income_150000_to_199999                                                    -0.326678
# income_more_than_200000                                                    -0.173201
# median_income                                                              -0.220892
# mean_income                                                                -0.169940
# totla_housing_units                                                        -0.153253
# occupied_housing_units                                                     -0.152422
# percent_occupied_housing_units                                             -0.625912
# percent_vacant_housing_units                                                0.625912
# margin_of_error_rental_vacancy_rate                                         0.868570
# renter_occupied_units                                                      -0.133401
# percent_renter_occupied                                                    -0.397014
# percent_rent_less_than_500                                                  0.652978
# percent_rent_500_to_999                                                     0.353939
# percent_rent_1000_to_1499                                                  -0.255917
# percent_rent_2000_to_2499                                                  -0.272688
# percent_rent_2500_to_2999                                                  -0.279953
# percent_rent_3000_or_more                                                  -0.206015
# total_population                                                           -0.151351
# percent_male                                                                0.217773
# percent_female                                                             -0.217773
# percent_white                                                              -0.005858
# percent_black_or_african_american                                          -0.196955
# percent_american_indian_and_alaska_native                                   1.000000
# percent_asian                                                              -0.242717
# percent_hispanic_or_latino                                                 -0.235735
#
#                                            percent_asian  \
# none                                           -0.078457
# drought                                         0.078457
# households_total                                0.404750
# income_less_than_10000                         -0.310490
# income_10000_to_14999                          -0.429805
# income_15000_to_24999                          -0.539619
# income_25000_to_34999                          -0.614994
# income_35000_to_44999                          -0.669561
# income_50000_to_74999                          -0.601974
# income_75000_to_99999                          -0.283871
# income_100000_to_149999                         0.369893
# income_150000_to_199999                         0.676569
# income_more_than_200000                         0.750428
# median_income                                   0.733679
# mean_income                                     0.714736
# totla_housing_units                             0.398815
# occupied_housing_units                          0.404750
# percent_occupied_housing_units                  0.436982
# percent_vacant_housing_units                   -0.436982
# margin_of_error_rental_vacancy_rate            -0.268593
# renter_occupied_units                           0.376340
# percent_renter_occupied                         0.552828
# percent_rent_less_than_500                     -0.441692
# percent_rent_500_to_999                        -0.580067
# percent_rent_1000_to_1499                      -0.398115
# percent_rent_2000_to_2499                       0.604013
# percent_rent_2500_to_2999                       0.734416
# percent_rent_3000_or_more                       0.759435
# total_population                                0.389337
# percent_male                                   -0.227696
# percent_female                                  0.227696
# percent_white                                  -0.784975
# percent_black_or_african_american               0.454211
# percent_american_indian_and_alaska_native      -0.242717
# percent_asian                                   1.000000
# percent_hispanic_or_latino                      0.005485
#
#                                            percent_hispanic_or_latino
# none                                                        -0.647677
# drought                                                      0.647677
# households_total                                             0.197088
# income_less_than_10000                                       0.004461
# income_10000_to_14999                                       -0.040592
# income_15000_to_24999                                        0.000850
# income_25000_to_34999                                       -0.081785
# income_35000_to_44999                                        0.105614
# income_50000_to_74999                                        0.122662
# income_75000_to_99999                                        0.190913
# income_100000_to_149999                                      0.065894
# income_150000_to_199999                                     -0.047848
# income_more_than_200000                                     -0.106615
# median_income                                               -0.066881
# mean_income                                                 -0.093043
# totla_housing_units                                          0.199328
# occupied_housing_units                                       0.197088
# percent_occupied_housing_units                               0.409372
# percent_vacant_housing_units                                -0.409372
# margin_of_error_rental_vacancy_rate                         -0.221407
# renter_occupied_units                                        0.184537
# percent_renter_occupied                                      0.505534
# percent_rent_less_than_500                                  -0.170747
# percent_rent_500_to_999                                     -0.022454
# percent_rent_1000_to_1499                                    0.153226
# percent_rent_2000_to_2499                                   -0.025960
# percent_rent_2500_to_2999                                   -0.056615
# percent_rent_3000_or_more                                   -0.085035
# total_population                                             0.217526
# percent_male                                                -0.089337
# percent_female                                               0.089337
# percent_white                                               -0.359258
# percent_black_or_african_american                            0.195438
# percent_american_indian_and_alaska_native                   -0.235735
# percent_asian                                                0.005485
# percent_hispanic_or_latino                                   1.000000
#
# [36 rows x 36 columns]

# %%
# #Redefining Drought DF with each week 

# # droughtDF['drought'] = droughtDF['D0']+ droughtDF['D1']+droughtDF['D2'] + droughtDF['D3']+ droughtDF['D4']
# droughtDF['drought'] = 100 - droughtDF['None']
# droughtDF

# %%
# droughtDF['county'] = droughtDF.County.str.replace(" County", "")

# %%
# # correlationDF = droughtDF.corr()


# newMergedDF = pd.merge(droughtDF, censusDF, on="county")
# newCorrelationDF = newMergedDF.corr()

# %%
# # Set up the matplotlib figure
# f, ax = plt.subplots(figsize=(11, 9))

# # Generate a custom diverging colormap
# cmap = sns.diverging_palette(230, 20, as_cmap=True)

# # Draw the heatmap with the mask and correct aspect ratio
# fiveYearCorrelationHeatMap = sns.heatmap(newCorrelationDF[['drought']], cmap=cmap, center=0,
#             square=True, linewidths=.5, cbar_kws={"shrink": .5})

# fiveYearCorrelationHeatMap.figure.savefig('images/fiveYearCorrelationHeatMap.png')

# %%
sns.histplot(data=droughtDF['None'])
# Out:
# <AxesSubplot:xlabel='None', ylabel='Count'>

# %%
##Counties with Most Drought
droughtByCounty = droughtDF.groupby(['County']).agg({'None': ['mean'], 'D0': ['mean'],'D1': ['mean'],
                                   'D2': ['mean'],'D3': ['mean'],'D4':['mean']})


droughtByCounty['county'] = droughtByCounty.index.str.replace(" County", "")
droughtByCounty.columns = droughtByCounty.columns.droplevel()
droughtByCounty.columns = ['None', 'D0', 'D1', 'D2', 'D3', 'D4', 'County']
droughtByCounty.reset_index(drop=True, inplace=True)

# %%
droughtByCounty.columns
# Out:
# Index(['None', 'D0', 'D1', 'D2', 'D3', 'D4', 'County'], dtype='object')

# %%
droughtDF.columns
# Out:
# Index(['MapDate', 'FIPS', 'County', 'State', 'None', 'D0', 'D1', 'D2', 'D3',
#        'D4', 'ValidStart', 'ValidEnd', 'StatisticFormatID'],
#       dtype='object')

# %%
droughtByCounty.head(5)
# Out:
#         None         D0         D1         D2         D3         D4     County
# 0  41.416832  58.583168  42.890038  37.337328  30.854542   4.965038    Alameda
# 1  46.381718  53.618282  41.672863  40.213779  29.032786  23.996527     Alpine
# 2  51.215305  48.784695  40.939008  39.423168  27.058931  25.163053     Amador
# 3  43.132863  56.867137  41.758550  27.480916  25.595038  21.629580      Butte
# 4  48.396908  51.603092  41.656641  40.682366  36.599656  25.889885  Calaveras

# %%
##https://seaborn.pydata.org/examples/many_facets.html 
fig = plt.gcf()
fig.set_size_inches(16, 10)
droughtBarPlot = sns.barplot(x="County", y="D0", data=droughtByCounty, 
                             order=droughtByCounty.sort_values("D0", ascending = False).County,
                             color = "Red"
                            )
plt.ylabel("Average Drought Level (2015-2019)", size=15)
plt.xlabel("County", size=15)
droughtBarPlot.set_xticklabels(droughtBarPlot.get_xticklabels(), 
                          rotation=90, 
                          horizontalalignment='right')

droughtBarPlot.figure.savefig('images/droughtBarPlot.png')

# %%
##Counties with Most Drought 
droughtByCounty.sort_values(by=['None'])
# Out:
#          None         D0         D1         D2         D3         D4  \
# 36   4.701794  95.298206  67.353817  54.688779  27.568244   0.000000
# 29   7.773435  92.226565  81.684962  58.338473  41.221374  29.687443
# 12   9.039656  90.960344  78.658779  49.646718  10.340305   0.000000
# 18  16.004809  83.995191  73.791947  58.044733  41.524389  35.124237
# 55  16.030534  83.969466  81.679389  60.485954  44.549656  41.032519
# 41  16.030687  83.969313  81.618931  61.116336  42.244924  40.633282
# 39  16.804847  83.195153  62.779733  49.625458  41.123053  38.316756
# 32  18.692901  81.307099  62.555802  40.716565  10.863473   0.130229
# 34  19.293817  80.706183  46.882939  42.174504  40.439313  31.139008
# 14  26.080573  73.919427  60.407366  43.664427  41.069160  29.701221
# 35  28.475191  71.524809  56.122061  32.115916  14.003588   0.239962
# 15  29.032939  70.967061  62.268550  44.002023  41.221374  39.587786
# 13  31.059427  68.940573  44.752901  37.915496  23.413702   6.844084
# 9   31.543855  68.456145  52.892137  42.897405  41.018282  34.733282
# 26  31.745992  68.254008  46.985038  38.522061  34.059924  22.405687
# 23  32.398626  67.601374  47.126947  41.414351  40.867748  25.954198
# 53  35.325878  64.674122  48.777137  43.250229  41.187786  39.711756
# 19  35.719962  64.280038  46.988244  42.468779  40.808893  31.128855
# 49  38.095611  61.904389  45.506336  41.133817  40.326107  25.954198
# 10  38.538550  61.461450  48.872405  27.480916  23.842366   3.332481
# 5   38.659313  61.340687  48.921260  32.372290  26.037290   6.910649
# 21  39.637099  60.362901  44.876183  40.957214  40.513931  31.914885
# 47  39.733397  60.266603  41.297863  35.028359  25.881870   2.387176
# 56  39.852824  60.147176  47.016298  37.391145  27.000649  21.793664
# 16  39.885038  60.114962  49.609580  25.445382  12.505649   0.000000
# 42  40.363321  59.636679  41.801908  35.642290  27.325000   6.428092
# 6   41.185611  58.814389  41.505229  37.812481  29.393702   2.535802
# 51  41.317176  58.682824  44.728435  27.412481  20.629046   2.687824
# 0   41.416832  58.583168  42.890038  37.337328  30.854542   4.965038
# 27  42.129847  57.870153  35.374771  24.730534  19.542710   0.013168
# 54  42.960802  57.039198  43.292481  40.811183  40.316947  26.803779
# 3   43.132863  56.867137  41.758550  27.480916  25.595038  21.629580
# 50  43.223321  56.776679  44.392672  27.480916  25.954198  24.427481
# 57  43.665573  56.334427  42.312786  27.480916  25.673664  23.551756
# 43  44.043893  55.956107  29.684427  24.568931  14.672252   0.000000
# 46  44.191031  55.808969  36.056832  27.256832   6.344542   0.006107
# 24  44.523397  55.476603  38.668626  25.311412  22.338359   5.378244
# 40  45.295916  54.704084  27.320534  24.045802  18.981985   0.000000
# 22  45.365382  54.634618  35.564427  21.478206   4.951603   0.000000
# 25  45.503092  54.496908  42.030000  40.762137  39.010534  22.990573
# 52  45.796374  54.203626  37.036221  23.345153   2.276221   0.000000
# 37  45.836679  54.163321  27.408282  24.032252   0.958244   0.000000
# 48  45.997214  54.002786  28.303130  22.785496   3.852901   0.000000
# 20  46.166985  53.833015  27.344924  22.474809   0.886145   0.000000
# 1   46.381718  53.618282  41.672863  40.213779  29.032786  23.996527
# 38  46.867481  53.132519  43.323015  40.907977  37.229160  25.948397
# 28  47.166298  52.833702  38.258015  29.029695  25.219771  19.743473
# 44  47.194046  52.805954  35.181489  24.541985  15.107557   3.070076
# 30  48.008282  51.991718  39.364427  29.035954  25.166908  20.160496
# 4   48.396908  51.603092  41.656641  40.682366  36.599656  25.889885
# 45  49.488130  50.511870  41.628130  31.043168  25.749618  18.550115
# 33  49.650000  50.350000  41.961985  39.375611  27.344275  24.043969
# 8   50.270840  49.729160  40.620725  31.573168  25.793550  21.047557
# 31  50.762290  49.237710  41.367595  29.021221  25.484275  18.884237
# 17  51.172137  48.827863  41.122672  30.284008  25.268321  19.042672
# 2   51.215305  48.784695  40.939008  39.423168  27.058931  25.163053
# 11  54.047061  45.952939  28.557977  19.402901   5.827977   0.000000
# 7   56.020878  43.979122  25.131336  12.608282   0.000000   0.000000
#
#              County
# 36        San Diego
# 29           Orange
# 12         Imperial
# 18      Los Angeles
# 55          Ventura
# 41    Santa Barbara
# 39  San Luis Obispo
# 32        Riverside
# 34       San Benito
# 14             Kern
# 35   San Bernardino
# 15            Kings
# 13             Inyo
# 9            Fresno
# 26         Monterey
# 23           Merced
# 53           Tulare
# 19           Madera
# 49       Stanislaus
# 10            Glenn
# 5            Colusa
# 21         Mariposa
# 47           Solano
# 56             Yolo
# 16             Lake
# 42      Santa Clara
# 6      Contra Costa
# 51           Tehama
# 0           Alameda
# 27             Napa
# 54         Tuolumne
# 3             Butte
# 50           Sutter
# 57             Yuba
# 43       Santa Cruz
# 46         Siskiyou
# 24            Modoc
# 40        San Mateo
# 22        Mendocino
# 25             Mono
# 52          Trinity
# 37    San Francisco
# 48           Sonoma
# 20            Marin
# 1            Alpine
# 38      San Joaquin
# 28           Nevada
# 44           Shasta
# 30           Placer
# 4         Calaveras
# 45           Sierra
# 33       Sacramento
# 8         El Dorado
# 31           Plumas
# 17           Lassen
# 2            Amador
# 11         Humboldt
# 7         Del Norte

# %%
## Scatter Plot 

scatterPlotDroughtvsHispanic = sns.scatterplot(data=mergedDF, x='drought', y='percent_hispanic_or_latino')
plt.ylabel("Percent Hispanic or Latino", size=15)
plt.xlabel("Drought Percentage", size=15)

scatterPlotDroughtvsHispanic.figure.savefig('images/scatterPlotDroughtvsHispanic.png')

# %%
## Scatter Plot 

scatterPlotDroughtvsMedianIncome = sns.scatterplot(data=mergedDF, x='drought', y='median_income')
plt.ylabel("Median Income", size=15)
plt.xlabel("Drought Percentage", size=15)

scatterPlotDroughtvsMedianIncome.figure.savefig('images/scatterPlotDroughtvsMedianIncome.png')

# %%
highestAndLowestDroughtDF = mergedDF.loc[mergedDF['county'].isin(['San Diego', 'Orange','Imperial','Riverside','San Bernardino','Mariposa','Lassen','Plumas','Calaveras','Tuolumne'])]
highestAndLowestDroughtDF.columns
# Out:
# Index(['none', 'drought', 'county', 'id', 'Geographic Area Name',
#        'households_total', 'income_less_than_10000', 'income_10000_to_14999',
#        'income_15000_to_24999', 'income_25000_to_34999',
#        'income_35000_to_44999', 'income_50000_to_74999',
#        'income_75000_to_99999', 'income_100000_to_149999',
#        'income_150000_to_199999', 'income_more_than_200000', 'median_income',
#        'mean_income', 'totla_housing_units', 'occupied_housing_units',
#        'percent_occupied_housing_units', 'percent_vacant_housing_units',
#        'margin_of_error_rental_vacancy_rate', 'renter_occupied_units',
#        'percent_renter_occupied', 'percent_rent_less_than_500',
#        'percent_rent_500_to_999', 'percent_rent_1000_to_1499',
#        'percent_rent_2000_to_2499', 'percent_rent_2500_to_2999',
#        'percent_rent_3000_or_more', 'total_population', 'percent_male',
#        'percent_female', 'percent_white', 'percent_black_or_african_american',
#        'percent_american_indian_and_alaska_native', 'percent_asian',
#        'percent_hispanic_or_latino'],
#       dtype='object')

# %%
plt.rcParams["figure.figsize"] = (10, 5)
ax = sns.barplot(x="county", y="median_income", data=highestAndLowestDroughtDF)

# %%
## Create scatterplot of demographic indicators vs Drought Conditions

# %%
droughtDF['date'] = pd.to_datetime(droughtDF['MapDate'], format='%Y%m%d')

# %%
# calaverasDF = droughtDF[['MapDate', 'drought']][droughtDF['county']=='Calaveras']


# sns.barplot(x='MapDate', y='drought', data=calaverasDF)
# Out:
# <AxesSubplot:xlabel='MapDate', ylabel='drought'>

# %%
droughtDF

# %%
#Work on getting these plots to be more readable and then try on the rest of counties 

smallDF = droughtDF[droughtDF['county'].isin(('Yuba', 'Alameda'))]

g = sns.FacetGrid(smallDF, col="county", col_wrap=2)
g.map(sns.barplot, x='date', y='drought', data=smallDF, width=8)
# Out:
# /Users/andrew/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:645: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-08f87f476c00> in <module>
#       4
#       5 g = sns.FacetGrid(smallDF, col="county", col_wrap=2)
# ----> 6 g.map(sns.barplot, x='date', y='drought', data=smallDF, width=8)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     682
#     683             # Draw the plot
# --> 684             self._facet_plot(func, ax, plot_args, kwargs)
#     685
#     686         # Finalize the annotations and layout
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     772                 plot_kwargs[key] = val
#     773             plot_args = []
# --> 774         func(*plot_args, **plot_kwargs)
#     775
#     776         # Sort out the supporting information
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3175         ax = plt.gca()
#    3176
# -> 3177     plotter.plot(ax, kwargs)
#    3178     return ax
#    3179
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1637     def plot(self, ax, bar_kws):
#    1638         """Make the plot."""
# -> 1639         self.draw_bars(ax, bar_kws)
#    1640         self.annotate_axes(ax)
#    1641         if self.orient == "h":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in draw_bars(self, ax, kws)
#    1602
#    1603             # Draw the bars
# -> 1604             barfunc(barpos, self.statistic, self.width,
#    1605                     color=self.colors, align="center", **kws)
#    1606
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: bar() got multiple values for argument 'width'
